# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Importing Libraries

# %%
# %pip install decision-tree-id3
# %pip install six
import matplotlib.pyplot as plt
import pandas as pd
import six
import sys
sys.modules['sklearn.externals.six'] = six
# Out:
# Requirement already satisfied: decision-tree-id3 in c:\users\varan\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: nose>=1.1.2 in c:\users\varan\anaconda3\lib\site-packages (from decision-tree-id3) (1.3.7)
# Requirement already satisfied: scikit-learn>=0.17 in c:\users\varan\anaconda3\lib\site-packages (from decision-tree-id3) (1.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\varan\anaconda3\lib\site-packages (from decision-tree-id3) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\varan\anaconda3\lib\site-packages (from scikit-learn>=0.17->decision-tree-id3) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\varan\anaconda3\lib\site-packages (from scikit-learn>=0.17->decision-tree-id3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\varan\anaconda3\lib\site-packages (from scikit-learn>=0.17->decision-tree-id3) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six in c:\users\varan\appdata\roaming\python\python312\site-packages (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Reading Data

# %%
tennis_data = pd.read_csv('PlayTennis.csv')
tennis_data.head()
# Out:
#     Outlook Temperature Humidity    Wind PlayTennis
# 0     Sunny         Hot     High    Weak         No
# 1     Sunny         Hot     High  Strong         No
# 2  Overcast         Hot     High    Weak        Yes
# 3      Rain        Mild     High    Weak        Yes
# 4      Rain        Cool   Normal    Weak        Yes

# %% [markdown]
# ## Converting data to numericals

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# Converting string labels into numbers.
tennis_data['Outlook'] = le.fit_transform(tennis_data['Outlook'])
tennis_data['Temperature'] = le.fit_transform(tennis_data['Temperature'])
tennis_data['Humidity'] = le.fit_transform(tennis_data['Humidity'])
tennis_data['Wind'] = le.fit_transform(tennis_data['Wind'])
tennis_data['PlayTennis'] = le.fit_transform(tennis_data['PlayTennis'])

# %% [markdown]
# ### Seperate Features and Target

# %%
x = tennis_data['PlayTennis']
y = tennis_data.drop('PlayTennis', axis=1)
print(x)
print(y)
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# 14    1
# Name: PlayTennis, dtype: int32
#     Outlook  Temperature  Humidity  Wind
# 0         2            1         0     1
# 1         2            1         0     0
# 2         0            1         0     1
# 3         1            2         0     1
# 4         1            0         1     1
# 5         1            0         1     0
# 6         0            0         1     0
# 7         2            2         0     1
# 8         2            0         1     1
# 9         1            2         1     1
# 10        2            2         1     0
# 11        0            2         0     0
# 12        0            1         1     1
# 13        1            2         0     0
# 14        2            1         1     1

# %% [markdown]
# ## Spliting Data into Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(y, x, test_size=0.4, random_state=0)

# %% [markdown]
# ## Fitting Model

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf = clf.fit(x_train, y_train)
fig, axes = plt.subplots(figsize = (6,8))
# tree.plot_tree(clf)
tree.plot_tree(clf,
               feature_names = ['Outlook', 'Temperature', 'Humidity', 'Wind'],
               filled = True)
plt.show()

# %% [markdown]
# ## Predicting

# %%
x_pred = clf.predict(x_test)
print(x_pred)
# Out:
# [0 1 0 1 0 0]

# %% [markdown]
# ## Evaluating Model
# Check accuracy, precision, recall, f1-score and support

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# Create a decision tree classifier
estimator = DecisionTreeClassifier()

# Train the model
estimator.fit(x_train, y_train)

# Make predictions
x_pred = estimator.predict(x_test)

# Print classification report
print(classification_report(y_test, x_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         1
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.50         6
#    macro avg       0.62      0.70      0.49         6
# weighted avg       0.88      0.50      0.54         6

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import accuracy_score
print('Accuracy Score on train data: ', accuracy_score(y_test,x_pred))
# Out:
# Accuracy Score on train data:  0.5
